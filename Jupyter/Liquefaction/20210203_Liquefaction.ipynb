# %% [markdown]
# # Import and Setup

# %% [markdown]
# Adjust cell width to view more content

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
# Out:
# <style>.container { width:95% !important; }</style>

# %% [markdown]
# Import general packages and YLXPS-related packages

# %%
import numpy as np
import matplotlib.pyplot as plt
import sys 
import os 
import scipy
import importlib

sys.path.insert(0, '../../purity-monitor/')
sys.path.insert(0, '../analysis/')
import HelperClasses as Dataset
import StandMonitor as Monitor
import PlotFunctions as Plt

# %% [markdown]
# # Data Read-In

# %%
File = 'C:/Data/StandStatus/20210203.h5'
Sensors = Monitor.SensorData(Filepath=File)
Sensors.GetData()
Sensors.PlotData(Selection='Temperature', Ticks=[1,20], XRange=0, XTicks=2, YRange=[-110,30])
Sensors.PlotData(Selection='Xenon Pressure', Ticks=[0,100], XRange=0, YRange=[0,800])
Sensors.PlotData(Selection='System Pressure', Ticks=[0,5], XRange=0, YRange=[-15,12])

# %%
D1 = Dataset.Dataset(Path='C:/Data/20210203/', Selection='*XenonGas*')
D1.RunStandardAnalysis()
D1.ShowAmplitudeVsTime(YTicks=10, YMax=150)
D1.ShowBaselineNoise()
# Out:
#  | Filename... C:/Data/20210203\XenonGas_Au-Thorslabs_C-100V_A-1500V_1.h5
#  | Number of files in ch1...	 87/87
#  | Number of files in ch2...	 87/87
#  | Processing data in channel 1...
#  | Processing data in channel 2...
#  | Time elapsed:  11.8125 sec
# Ticks:  10

# %%
D2 = Dataset.Dataset(Path='C:/Data/20210203/', Selection='*Filling*')
D2.RunStandardAnalysis()
D2.ShowAmplitudeVsTime(YTicks=10, YMax=150)
D2.ShowBaselineNoise()
# Out:
#  | Filename... C:/Data/20210203\Filling_Au-Thorslabs_C-100V_A-1500V_1.h5
#  | Number of files in ch1...	 537/537
#  | Number of files in ch2...	 537/537
#  | Filename... C:/Data/20210203\Filling_Au-Thorslabs_C-100V_A-1500V_2.h5
#  | Number of files in ch1...	 197/734
#  | Number of files in ch2...	 197/734
#  | Filename... C:/Data/20210203\Filling_Au-Thorslabs_C-200V_A-2500V_1.h5
#  | Number of files in ch1...	 79/813
#  | Number of files in ch2...	 79/813
#  | Filename... C:/Data/20210203\Filling_Au-Thorslabs_C-200V_A-2500V_2.h5
#  | Number of files in ch1...	 261/1074
#  | Number of files in ch2...	 261/1074
#  | Filename... C:/Data/20210203\Filling_Au-Thorslabs_C-200V_A-2500V_3.h5
#  | Number of files in ch1...	 127/1201
#  | Number of files in ch2...	 127/1201
#  | Filename... C:/Data/20210203\Filling_Au-Thorslabs_C-200V_A-2500V_4.h5
#  | Number of files in ch1...	 191/1392
#  | Number of files in ch2...	 191/1392
#  | Processing data in channel 1...
#  | Processing data in channel 2...
#  | Time elapsed:  41.34375 sec
# Ticks:  10

# %%
Plt.PltWfm(Time=D2.Ch[0].Time,
           Data=[np.mean(D2.Ch[0].AmpClean, axis=0), np.mean(D2.Ch[1].AmpClean, axis=0)*-1],
           Legend=['Anode'],
           XTicks=100,
           YTicks=5,
           SaveName='avg_waveform',
           Color='k')
plt.ylim(-30,20)
plt.xlim(-100,500)
# Out:
# (-100.0, 500.0)

# %%
D3 = Dataset.Dataset(Path='C:/Data/20210203/', Selection='*SwapAmp*')
D3.RunStandardAnalysis()
D3.ShowAmplitudeVsTime(YTicks=50, YMax=500)
D3.ShowBaselineNoise()
# Out:
#  | Filename... C:/Data/20210203\LXe_Au-Thorslabs_SwapAmp_C-200V_A-2500V_1.h5
#  | Number of files in ch1...	 45/45
#  | Number of files in ch2...	 45/45
#  | Processing data in channel 1...
#  | Processing data in channel 2...
#  | Time elapsed:  45.03125 sec
# Ticks:  50

# %%
Plt.PltWfm(Time=D3.Ch[0].Time,
           Data=[np.mean(D3.Ch[0].AmpClean, axis=0), np.mean(D3.Ch[1].AmpClean, axis=0)*-1],
           Legend=['Anode'],
           XTicks=100,
           YTicks=50,
           SaveName='avg_waveform',
           Color='k')
plt.ylim(-500,20)
plt.xlim(-100,500)
# Out:
# (-100.0, 500.0)
