# %% [markdown]
# # Import and Setup

# %% [markdown]
# Adjust cell width to view more content

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
# Out:
# <style>.container { width:95% !important; }</style>

# %% [markdown]
# Import general packages and YLXPS-related packages

# %%
import numpy as np
import matplotlib.pyplot as plt
import sys 
import os 
import scipy
import importlib

sys.path.insert(0, '../../purity-monitor/')
sys.path.insert(0, '../analysis/')
import HelperClasses as Dataset
import StandMonitor as Monitor
import PlotFunctions as Plt

# %% [markdown]
# # Data Read-In

# %%
File = 'C:/Data/StandStatus/20210209.h5'
Sensors = Monitor.SensorData(Filepath=File)
Sensors.GetData()
Sensors.PlotData(Selection='Temperature', Ticks=[1,20], XRange=0, XTicks=1, YRange=[-120,30])
Sensors.PlotData(Selection='Xenon Pressure', Ticks=[0,100], XRange=0, YRange=[0,800])
Sensors.PlotData(Selection='System Pressure', Ticks=[0,5], XRange=0, YRange=[-15,20])

# %%
File = 'C:/Data/StandStatus/20210210.h5'
Sensors = Monitor.SensorData(Filepath=File)
Sensors.GetData()
Sensors.PlotData(Selection='Temperature', Ticks=[1,20], XRange=0, XTicks=1, YRange=[-120,30])
Sensors.PlotData(Selection='Xenon Pressure', Ticks=[0,100], XRange=0, YRange=[0,800])
Sensors.PlotData(Selection='System Pressure', Ticks=[0,5], XRange=0, YRange=[-15,20])

# %%
D1 = Dataset.Dataset(Path='C:/Data/20210210/', Selection='*Filling*')
D1.RunStandardAnalysis()
D1.ShowAmplitudeVsTime(YTicks=10, YMax=150)
D1.ShowBaselineNoise()
# Out:
#  | Filename... C:/Data/20210210\Filling_Au-Thorslabs_C-120V_A-1500V_1.h5
#  | Number of files in ch1...	 228/228
#  | Number of files in ch2...	 228/228
#  | Filename... C:/Data/20210210\Filling_Au-Thorslabs_C-120V_A-1500V_10.h5
#  | Number of files in ch1...	 26/254
#  | Number of files in ch2...	 26/254
#  | Filename... C:/Data/20210210\Filling_Au-Thorslabs_C-120V_A-1500V_2.h5
#  | Number of files in ch1...	 122/376
#  | Number of files in ch2...	 122/376
#  | Filename... C:/Data/20210210\Filling_Au-Thorslabs_C-120V_A-1500V_3.h5
#  | Number of files in ch1...	 131/507
#  | Number of files in ch2...	 131/507
#  | Filename... C:/Data/20210210\Filling_Au-Thorslabs_C-120V_A-1500V_4 - Copy.h5
#  | Number of files in ch1...	 162/669
#  | Number of files in ch2...	 162/669
#  | Filename... C:/Data/20210210\Filling_Au-Thorslabs_C-120V_A-1500V_5.h5
#  | Number of files in ch1...	 191/860
#  | Number of files in ch2...	 191/860
# ...

# %%
D2 = Dataset.Dataset(Path='C:/Data/20210210/', Selection='*AttachFiber*')
D2.RunStandardAnalysis()
Plt.PltWfm(Time=D1.Ch[0].Time,
           Data=[np.mean(D1.Ch[0].AmpClean, axis=0), np.mean(D1.Ch[1].AmpClean/-70.0, axis=0)],
           Legend=['Anode'],
           XTicks=100,
           YTicks=1,
           SaveName='avg_waveform',
           Color='k')
# Out:
#  | Filename... C:/Data/20210210\AttachFiber_Au-Thorslabs_C-250V_A-3000V_1.h5
#  | Number of files in ch1...	 96/96
#  | Number of files in ch2...	 96/96
#  | Processing data in channel 1...
#  | Processing data in channel 2...
#  | Time elapsed:  64.734375 sec

# %%
D3 = Dataset.Dataset(Path='C:/Data/20210210/', Selection='*RemoveFiber*')
D3.RunStandardAnalysis()
Plt.PltWfm(Time=D3.Ch[0].Time,
           Data=[np.mean(D3.Ch[0].AmpClean, axis=0), np.mean(D3.Ch[1].AmpClean/-70.0, axis=0)],
           Legend=['Anode'],
           XTicks=100,
           YTicks=1,
           SaveName='avg_waveform',
           Color='k')
# Out:
#  | Filename... C:/Data/20210210\RemoveFiber_Au-Thorslabs_C-250V_A-3000V_1.h5
#  | Number of files in ch1...	 267/267
#  | Number of files in ch2...	 267/267
#  | Processing data in channel 1...
#  | Processing data in channel 2...
#  | Time elapsed:  74.9375 sec

# %%
# Plt.PltWfm(Time=D2.Ch[0].Time,
#            Data=[np.mean(D2.Ch[0].AmpClean, axis=0), np.mean(D2.Ch[1].AmpClean/-1.0, axis=0)],
#            Legend=['Anode'],
#            XTicks=100,
#            YTicks=1,
#            SaveName='avg_waveform',
#            Color='k')
# # plt.ylim(-5,5)
# plt.xlim(-100,500)

# %%
# Plt.PltWfm(Time=D2.Ch[0].Time,
#            Data=[np.mean(D1.Ch[0].AmpClean, axis=0)-np.mean(D2.Ch[0].AmpClean, axis=0), np.mean(D1.Ch[1].AmpClean/-70.0, axis=0)],
#            Legend=['Anode'],
#            XTicks=100,
#            YTicks=1,
#            SaveName='avg_waveform',
#            Color='k')
# # plt.ylim(-5,5)
# plt.xlim(-100,500)

# %%
# D3 = Dataset.Dataset(Path='C:/Data/20210210/', Selection='*Purify*')
# D3.RunStandardAnalysis()
# D3.ShowAmplitudeVsTime(YTicks=10, YMax=150)

# %%
# Plt.PltWfm(Time=D3.Ch[0].Time,
#            Data=[np.mean(D3.Ch[0].AmpClean, axis=0), np.mean(D3.Ch[1].AmpClean/-10.0, axis=0)],
#            Legend=['Anode'],
#            XTicks=100,
#            YTicks=1,
#            SaveName='avg_waveform',
#            Color='k')
# # plt.ylim(-5,5)
# plt.xlim(-100,500)
