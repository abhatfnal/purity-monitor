# %% [markdown]
# # Import and Setup

# %%
import numpy as np

import matplotlib.pyplot as plt
plt.style.use('../style.mplstyle')
colors = plt.rcParams['axes.prop_cycle'].by_key()['color']

import sys 
sys.path.insert(0, '../../../purity-monitor/')
sys.path.insert(0, '../WaveformAnalysis/')
import Dataset

# %% [markdown]
# # Data Read-In

# %%
D1 = Dataset.Dataset(Path='C:/Data/20210528/', Selection='GXe*')
D1.RunStandardAnalysis()
D1.ShowAmplitudeVsTime(YTicks=20, YMax=200)

plt.figure()
plt.xlabel('Time [us]')
plt.ylabel('Amplitude [mV]')
plt.plot(D1.Ch[0].Time, np.mean(D1.Ch[0].Amp,axis=0))
plt.plot(D1.Ch[0].Time, np.mean(D1.Ch[1].Amp,axis=0))
plt.xlim(-100,1000)
# Out:
#  | Filename... C:/Data/20210528\GXe_Photocathode_Sumita_C-200V_A-1200V_0.h5
#  | Number of files in ch1...	 80/80
#  | Number of files in ch2...	 80/80
#  | Filename... C:/Data/20210528\GXe_Photocathode_Sumita_C-200V_A-1200V_2_0.h5
#  | Number of files in ch1...	 200/280
#  | Number of files in ch2...	 200/280
#  | Filename... C:/Data/20210528\GXe_Photocathode_Sumita_C-200V_A-1200V_2_1.h5
#  | Number of files in ch1...	 114/394
#  | Number of files in ch2...	 114/394
#  | Filename... C:/Data/20210528\GXe_Photocathode_Sumita_C-200V_A-1200V_2_2.h5
#  | Number of files in ch1...	 100/494
#  | Number of files in ch2...	 100/494
#  | Filename... C:/Data/20210528\GXe_Photocathode_Sumita_C-200V_A-1200V_2_3.h5
#  | Number of files in ch1...	 100/594
#  | Number of files in ch2...	 100/594
#  | Filename... C:/Data/20210528\GXe_Photocathode_Sumita_C-200V_A-1200V_2_4.h5
#  | Number of files in ch1...	 100/694
#  | Number of files in ch2...	 100/694
#  | Filename... C:/Data/20210528\GXe_Photocathode_Sumita_C-200V_A-1200V_2_5.h5
#  | Number of files in ch1...	 100/794
#  | Number of files in ch2...	 100/794
#  | Filename... C:/Data/20210528\GXe_Photocathode_Sumita_C-200V_A-1200V_2_6.h5
#  | Number of files in ch1...	 100/894
#  | Number of files in ch2...	 100/894
#  | Filename... C:/Data/20210528\GXe_Photocathode_Sumita_C-200V_A-1200V_2_7.h5
#  | Number of files in ch1...	 100/994
#  | Number of files in ch2...	 100/994
#  | Filename... C:/Data/20210528\GXe_Photocathode_Sumita_C-200V_A-1200V_2_8.h5
#  | Number of files in ch1...	 100/1094
#  | Number of files in ch2...	 100/1094
#  | Filename... C:/Data/20210528\GXe_Photocathode_Sumita_C-200V_A-1200V_2_9.h5
#  | Number of files in ch1...	 67/1161
#  | Number of files in ch2...	 67/1161
#  | Filename... C:/Data/20210528\GXe_Photocathode_Sumita_FiberRack_C-200V_A-1200V_0.h5
#  | Number of files in ch1...	 100/1261
#  | Number of files in ch2...	 100/1261
#  | Filename... C:/Data/20210528\GXe_Photocathode_Sumita_FiberRack_C-200V_A-1200V_1.h5
#  | Number of files in ch1...	 100/1361
#  | Number of files in ch2...	 100/1361
#  | Filename... C:/Data/20210528\GXe_Photocathode_Sumita_FiberRack_C-200V_A-1200V_2.h5
#  | Number of files in ch1...	 47/1408
#  | Number of files in ch2...	 47/1408
#  | Filename... C:/Data/20210528\GXe_Photocathode_Sumita_Fiber_C-200V_A-1200V_0.h5
#  | Number of files in ch1...	 100/1508
#  | Number of files in ch2...	 100/1508
#  | Filename... C:/Data/20210528\GXe_Photocathode_Sumita_Fiber_C-200V_A-1200V_1.h5
#  | Number of files in ch1...	 100/1608
#  | Number of files in ch2...	 100/1608
#  | Filename... C:/Data/20210528\GXe_Photocathode_Sumita_Fiber_C-200V_A-1200V_2.h5
#  | Number of files in ch1...	 100/1708
#  | Number of files in ch2...	 100/1708
#  | Filename... C:/Data/20210528\GXe_Photocathode_Sumita_Fiber_C-200V_A-1200V_3.h5
#  | Number of files in ch1...	 100/1808
#  | Number of files in ch2...	 100/1808
#  | Filename... C:/Data/20210528\GXe_Photocathode_Sumita_Fiber_C-200V_A-1200V_4.h5
#  | Number of files in ch1...	 100/1908
#  | Number of files in ch2...	 100/1908
#  | Filename... C:/Data/20210528\GXe_Photocathode_Sumita_Fiber_C-200V_A-1200V_5.h5
#  | Number of files in ch1...	 100/2008
#  | Number of files in ch2...	 100/2008
#  | Filename... C:/Data/20210528\GXe_Photocathode_Sumita_Fiber_C-200V_A-1200V_6.h5
#  | Number of files in ch1...	 100/2108
#  | Number of files in ch2...	 100/2108
#  | Filename... C:/Data/20210528\GXe_Photocathode_Sumita_Fiber_C-200V_A-1200V_7.h5
#  | Number of files in ch1...	 100/2208
#  | Number of files in ch2...	 100/2208
#  | Filename... C:/Data/20210528\GXe_Photocathode_Sumita_Fiber_C-200V_A-1200V_8.h5
#  | Number of files in ch1...	 100/2308
#  | Number of files in ch2...	 100/2308
#  | Filename... C:/Data/20210528\GXe_Photocathode_Sumita_Fiber_C-200V_A-1200V_9.h5
#  | Number of files in ch1...	 94/2402
#  | Number of files in ch2...	 94/2402
#  | Processing data in channel 1...
#  | Processing data in channel 2...
#  | Time elapsed:  5.578125 sec
# (-100.0, 1000.0)
