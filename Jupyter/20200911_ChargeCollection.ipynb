# %% [markdown]
# # Import and Setup

# %% [markdown]
# Adjust cell width to view more content

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %% [markdown]
# Import general packages

# %%
import numpy as np
import matplotlib.pyplot as plt
import glob
import os
import datetime
from matplotlib.patches import Rectangle

# %% [markdown]
# Import YLXPS-related packages

# %%
import sys 
sys.path.insert(0, '/gpfs/loomis/project/david_moore/aj487/purity_monitor/')
sys.path.insert(0, '/gpfs/loomis/project/david_moore/aj487/purity_monitor/analysis/')
import StandMonitor
import WaveformClass as Wvf
import HelperClasses as HelpC
import RunAnalysis as An
import PlotFunctions as Plt

# %% [markdown]
# # Data Read-In

# %%
class Namespace:
    def __init__(self, **kwargs):
        self.__dict__.update(kwargs)

# %% [markdown]
# # Analysis

# %%
FilePath = '/project/fas/david_moore/zl423/PurityData/20200911/'
Files = sorted(glob.glob(FilePath+'GAr*10cm*'))
arg = Namespace(filepath=Files, dirpath=None, txt=False, show=True)
for ii,File in enumerate(Files): 
    print(ii, File)
# Out:
# 0 /project/fas/david_moore/zl423/PurityData/20200911/GAr_InnerChamberClosed_Au-Thorslabs_10cm_C-500V_A-500V_1.h5
# 1 /project/fas/david_moore/zl423/PurityData/20200911/GAr_InnerChamberClosed_Au-Thorslabs_10cm_C-500V_A-500V_2.h5
# 2 /project/fas/david_moore/zl423/PurityData/20200911/GAr_InnerChamberClosed_Au-Thorslabs_10cm_C-500V_A-500V_3.h5

# %% [markdown]
# ## Argon Measurement
# Argon was left in the chamber since September 10. See Jupyter notebook from 20200910 for comparison.

# %%
ch1 = Wvf.WFM(ID=1, Pol=1)
ch2 = Wvf.WFM(ID=2, Pol=-1)
channels = [ch1, ch2]

FileNames, Method = An.ChooseFilesToAnalyze(arg)
for File in FileNames: 
    An.ImportDataFromHDF5(File, channels)

An.DoAnalysis(channels)

ChargeCollection = ch1.Max / ch2.Max
DiffMinute = int((np.max(ch1.TimeStamp) - np.min(ch1.TimeStamp)).seconds/60.0 + 0.5)
XTicks = int((DiffMinute/12.0 + 0.5))+1
print(np.mean(ChargeCollection))
print(np.std(ChargeCollection)/np.sqrt(len(ChargeCollection)))
# Out:
#  | Filename... /project/fas/david_moore/zl423/PurityData/20200911/GAr_InnerChamberClosed_Au-Thorslabs_10cm_C-500V_A-500V_1.h5
#  | Number of files in ch1...	 11/11
#  | Number of files in ch2...	 11/11
#  | Filename... /project/fas/david_moore/zl423/PurityData/20200911/GAr_InnerChamberClosed_Au-Thorslabs_10cm_C-500V_A-500V_2.h5
#  | Number of files in ch1...	 33/44
#  | Number of files in ch2...	 33/44
#  | Filename... /project/fas/david_moore/zl423/PurityData/20200911/GAr_InnerChamberClosed_Au-Thorslabs_10cm_C-500V_A-500V_3.h5
#  | Number of files in ch1...	 24/68
#  | Number of files in ch2...	 24/68
#  | Processing data in channel 1...
#  | Processing data in channel 2...
#  | Time elapsed:  3.443395862 sec
# 0.49480312227231144
# 0.005630569964290149

# %%
Plt.PltTime(Time=ch1.TimeStamp,
            Data=[ch1.Max,ch2.Max,ChargeCollection*100],
            Legend=['Anode','Cathode','Charge Collection [\%]'],
            Label='Amplitude [mV]',
            XTicks=XTicks,
            YTicks=20,
            YRange=[0,100],
            SaveName='amp_ratio',
            Title='Charge Collection in Argon gas at 100 V/cm',
            Save=False)
# plt.savefig('amp.pdf', bbox_inches='tight')

# %%
Plt.PltTime(Time=ch1.TimeStamp,
        Data=[ch1.GradTime,ch2.GradTime,ch1.GradTime - ch2.GradTime],
        Legend=['Anode','Cathode','Drift Time [$\mu$s]'],
        Label='Peak Time [$\mu$s]',
        XTicks=XTicks,
        YTicks=10,
        YRange=[0,50],
        SaveName='drift_time',
        Save=False)

# %%
Plt.PltWfm(Time=ch1.Time,
           Data=list(ch1.AmpClean),
           Legend=['Anode'],
           XTicks=100,
           YTicks=10,
           SaveName='avg_waveform',
           Color='k')

Plt.PltWfm(Time=ch2.Time,
           Data=list(ch2.AmpClean),
           Legend=['Cathode'],
           XTicks=100,
           YTicks=20,
           SaveName='avg_waveform',
           Color='k')

# %%
endbin = ch1.FindTimeBin(-100)

noise = []
for x in ch1.AmpClean: 
    nn = np.std(x[:endbin])
    nn = np.sqrt(np.mean(x[:endbin]**2))
    noise.append(nn)
    
    
noise_avg = np.mean(noise)
noise_err = np.std(noise)
    
print(np.mean(noise))
fig = plt.figure(figsize=(8,6))
plt.xlim(0,10)
plt.hist(noise, bins=np.arange(0.0,10.0,0.1), histtype='step', align='mid', lw=2)
plt.xlabel('Baseline Noise [mV]', fontsize=16)
plt.ylabel('Counts/bin', fontsize=16)
plt.axvline(noise_avg, color='red')
# plt.title('Charge Collection = %.4f ± %.4f' % (avg,err))
rectangle = plt.Rectangle((noise_avg-noise_err,0), 2*noise_err, 100, fc='red',ec="red", alpha=0.05, fill=True)
plt.gca().add_patch(rectangle)
# plt.savefig('chargecollection_hist.pdf',bbox_inches='tight')
# Out:
# 3.0654077383644807

# %%
avg = np.mean(ChargeCollection)
err = np.std(ChargeCollection)/np.sqrt(len(ChargeCollection))

# %%
fig = plt.figure(figsize=(8,6))
plt.xlim(0.0,2.0)
plt.hist(ChargeCollection, bins=np.linspace(0.0,2.0,201), histtype='step', align='mid', lw=2)
plt.xlabel('Charge Collection', fontsize=16)
plt.ylabel('Counts/bin', fontsize=16)
plt.axvline(avg, color='red')
plt.title('Charge Collection = %.4f ± %.4f' % (avg,err))
rectangle = plt.Rectangle((avg-err,0), 2*err, 100, fc='red',ec="red", alpha=0.2, fill=True)
plt.gca().add_patch(rectangle)
plt.savefig('chargecollection_hist.pdf',bbox_inches='tight')

# %%
FilePath = '/project/fas/david_moore/zl423/PurityData/20200910/'
Files2 = sorted(glob.glob(FilePath+'Vacuum*InnerChamber*'))
arg2 = Namespace(filepath=Files2, dirpath=None, txt=False, show=True)
for ii,File in enumerate(Files2): 
    print(ii, File)
    
ch3 = Wvf.WFM(ID=1, Pol=1)
ch4 = Wvf.WFM(ID=2, Pol=-1)
channels2 = [ch3, ch4]

FileNames2, Method = An.ChooseFilesToAnalyze(arg2)
for File in FileNames2: 
    An.ImportDataFromHDF5(File, channels2)

An.DoAnalysis(channels2)

ChargeCollection2 = ch3.Max / ch4.Max
DiffMinute2 = int((np.max(ch3.TimeStamp) - np.min(ch3.TimeStamp)).seconds/60.0 + 0.5)
XTicks2 = int((DiffMinute2/12.0 + 0.5))+1
print(np.mean(ChargeCollection2))
print(np.std(ChargeCollection2)/np.sqrt(len(ChargeCollection2)))
# Out:
# 0 /project/fas/david_moore/zl423/PurityData/20200910/Vacuum_ClosedInnerChamber_Au-Thorslabs_10cm_C-100V_A-100V_1.h5
# 1 /project/fas/david_moore/zl423/PurityData/20200910/Vacuum_ClosedInnerChamber_Au-Thorslabs_10cm_C-100V_A-100V_2.h5
# 2 /project/fas/david_moore/zl423/PurityData/20200910/Vacuum_ClosedInnerChamber_Au-Thorslabs_10cm_C-100V_A-100V_3.h5
# 3 /project/fas/david_moore/zl423/PurityData/20200910/Vacuum_ClosedInnerChamber_Au-Thorslabs_10cm_C-100V_A-100V_4.h5
# 4 /project/fas/david_moore/zl423/PurityData/20200910/Vacuum_ClosedInnerChamber_Au-Thorslabs_10cm_C-100V_A-100V_5.h5
# 5 /project/fas/david_moore/zl423/PurityData/20200910/Vacuum_ClosedInnerChamber_Au-Thorslabs_10cm_C-100V_A-100V_6.h5
# 6 /project/fas/david_moore/zl423/PurityData/20200910/Vacuum_ClosedInnerChamber_Au-Thorslabs_10cm_C-500V_A-500V_1.h5
# 7 /project/fas/david_moore/zl423/PurityData/20200910/Vacuum_ClosedInnerChamber_Au-Thorslabs_10cm_C-500V_A-500V_2.h5
# 8 /project/fas/david_moore/zl423/PurityData/20200910/Vacuum_ClosedInnerChamber_Au-Thorslabs_10cm_C-500V_A-500V_3.h5
# 9 /project/fas/david_moore/zl423/PurityData/20200910/Vacuum_ClosedInnerChamber_Au-Thorslabs_10cm_C-500V_A-500V_4.h5
#  | Filename... /project/fas/david_moore/zl423/PurityData/20200910/Vacuum_ClosedInnerChamber_Au-Thorslabs_10cm_C-100V_A-100V_1.h5
#  | Number of files in ch1...	 25/25
#  | Number of files in ch2...	 25/25
#  | Filename... /project/fas/david_moore/zl423/PurityData/20200910/Vacuum_ClosedInnerChamber_Au-Thorslabs_10cm_C-100V_A-100V_2.h5
#  | Number of files in ch1...	 23/48
#  | Number of files in ch2...	 23/48
#  | Filename... /project/fas/david_moore/zl423/PurityData/20200910/Vacuum_ClosedInnerChamber_Au-Thorslabs_10cm_C-100V_A-100V_3.h5
#  | Number of files in ch1...	 35/83
#  | Number of files in ch2...	 35/83
#  | Filename... /project/fas/david_moore/zl423/PurityData/20200910/Vacuum_ClosedInnerChamber_Au-Thorslabs_10cm_C-100V_A-100V_4.h5
#  | Number of files in ch1...	 25/108
#  | Number of files in ch2...	 25/108
#  | Filename... /project/fas/david_moore/zl423/PurityData/20200910/Vacuum_ClosedInnerChamber_Au-Thorslabs_10cm_C-100V_A-100V_5.h5
#  | Number of files in ch1...	 27/135
#  | Number of files in ch2...	 27/135
#  | Filename... /project/fas/david_moore/zl423/PurityData/20200910/Vacuum_ClosedInnerChamber_Au-Thorslabs_10cm_C-100V_A-100V_6.h5
#  | Number of files in ch1...	 3/138
#  | Number of files in ch2...	 3/138
#  | Filename... /project/fas/david_moore/zl423/PurityData/20200910/Vacuum_ClosedInnerChamber_Au-Thorslabs_10cm_C-500V_A-500V_1.h5
#  | Number of files in ch1...	 16/154
#  | Number of files in ch2...	 16/154
#  | Filename... /project/fas/david_moore/zl423/PurityData/20200910/Vacuum_ClosedInnerChamber_Au-Thorslabs_10cm_C-500V_A-500V_2.h5
#  | Number of files in ch1...	 18/172
#  | Number of files in ch2...	 18/172
#  | Filename... /project/fas/david_moore/zl423/PurityData/20200910/Vacuum_ClosedInnerChamber_Au-Thorslabs_10cm_C-500V_A-500V_3.h5
#  | Number of files in ch1...	 16/188
#  | Number of files in ch2...	 16/188
#  | Filename... /project/fas/david_moore/zl423/PurityData/20200910/Vacuum_ClosedInnerChamber_Au-Thorslabs_10cm_C-500V_A-500V_4.h5
#  | Number of files in ch1...	 3/191
#  | Number of files in ch2...	 3/191
#  | Processing data in channel 1...
#  | Processing data in channel 2...
#  | Time elapsed:  16.943343751 sec
# 1.3599703301799049
# 0.013874581578850976

# %%
Plt.PltTime(Time=ch3.TimeStamp,
            Data=[ch3.Max,ch4.Max,ChargeCollection2*100],
            Legend=['Anode','Cathode','Charge Collection [\%]'],
            Label='Amplitude [mV]',
            XTicks=XTicks2,
            YTicks=100,
            YRange=[0,1500],
            SaveName='amp_ratio',
            Title='Charge Collection in Vacuum with Inner Chamber Closed at 20 V/cm',
            Save=False)
# plt.savefig('amp.pdf', bbox_inches='tight')

# %%
avg2 = np.mean(ChargeCollection2)
err2 = np.std(ChargeCollection2)/np.sqrt(len(ChargeCollection2))

print(avg2)
fig = plt.figure(figsize=(8,6))
plt.xlim(0.0,2.0)
plt.hist(ChargeCollection2, bins=np.linspace(0.0,2.0,201), histtype='step', align='mid', lw=2)
plt.xlabel('Charge Collection', fontsize=16)
plt.ylabel('Counts/bin', fontsize=16)
plt.axvline(avg2, color='red')
plt.title('Charge Collection = %.4f ± %.4f' % (avg2,err2))
rectangle = plt.Rectangle((avg2-err2,0), 2*err2, 10000, fc='red',ec="red", alpha=0.2, fill=True)
plt.gca().add_patch(rectangle)
plt.savefig('chargecollection_hist.pdf',bbox_inches='tight')
# Out:
# 1.3599703301799049

# %%
FilePath = '/project/fas/david_moore/zl423/PurityData/20200910/'
Files3 = sorted(glob.glob(FilePath+'GAr*ClosedInnerChamber*'))
arg3 = Namespace(filepath=Files3, dirpath=None, txt=False, show=True)
for ii,File in enumerate(Files3): 
    print(ii, File)
    
ch5 = Wvf.WFM(ID=1, Pol=1)
ch6 = Wvf.WFM(ID=2, Pol=-1)
channels3 = [ch5, ch6]

FileNames3, Method = An.ChooseFilesToAnalyze(arg3)
for File in FileNames3: 
    An.ImportDataFromHDF5(File, channels3)

An.DoAnalysis(channels3)

ChargeCollection3 = ch5.Max / ch6.Max
DiffMinute3 = int((np.max(ch5.TimeStamp) - np.min(ch5.TimeStamp)).seconds/60.0 + 0.5)
XTicks3 = int((DiffMinute3/12.0 + 0.5))+1
print(np.mean(ChargeCollection3))
print(np.std(ChargeCollection3)/np.sqrt(len(ChargeCollection3)))
# Out:
# 0 /project/fas/david_moore/zl423/PurityData/20200910/GAr_ClosedInnerChamber_Au-Thorslabs_10cm_C-500V_A-500V_1.h5
# 1 /project/fas/david_moore/zl423/PurityData/20200910/GAr_ClosedInnerChamber_Au-Thorslabs_10cm_C-500V_A-500V_2.h5
# 2 /project/fas/david_moore/zl423/PurityData/20200910/GAr_ClosedInnerChamber_Au-Thorslabs_10cm_C-500V_A-500V_3.h5
# 3 /project/fas/david_moore/zl423/PurityData/20200910/GAr_ClosedInnerChamber_Au-Thorslabs_10cm_C-500V_A-500V_4.h5
# 4 /project/fas/david_moore/zl423/PurityData/20200910/GAr_ClosedInnerChamber_Au-Thorslabs_10cm_C-500V_A-500V_5.h5
# 5 /project/fas/david_moore/zl423/PurityData/20200910/GAr_ClosedInnerChamber_Au-Thorslabs_10cm_C-500V_A-500V_6.h5
#  | Filename... /project/fas/david_moore/zl423/PurityData/20200910/GAr_ClosedInnerChamber_Au-Thorslabs_10cm_C-500V_A-500V_1.h5
#  | Number of files in ch1...	 12/12
#  | Number of files in ch2...	 12/12
#  | Filename... /project/fas/david_moore/zl423/PurityData/20200910/GAr_ClosedInnerChamber_Au-Thorslabs_10cm_C-500V_A-500V_2.h5
#  | Number of files in ch1...	 20/32
#  | Number of files in ch2...	 20/32
#  | Filename... /project/fas/david_moore/zl423/PurityData/20200910/GAr_ClosedInnerChamber_Au-Thorslabs_10cm_C-500V_A-500V_3.h5
#  | Number of files in ch1...	 16/48
#  | Number of files in ch2...	 16/48
#  | Filename... /project/fas/david_moore/zl423/PurityData/20200910/GAr_ClosedInnerChamber_Au-Thorslabs_10cm_C-500V_A-500V_4.h5
#  | Number of files in ch1...	 60/108
#  | Number of files in ch2...	 60/108
#  | Filename... /project/fas/david_moore/zl423/PurityData/20200910/GAr_ClosedInnerChamber_Au-Thorslabs_10cm_C-500V_A-500V_5.h5
#  | Number of files in ch1...	 249/357
#  | Number of files in ch2...	 249/357
#  | Filename... /project/fas/david_moore/zl423/PurityData/20200910/GAr_ClosedInnerChamber_Au-Thorslabs_10cm_C-500V_A-500V_6.h5
#  | Number of files in ch1...	 694/1051
#  | Number of files in ch2...	 694/1051
#  | Processing data in channel 1...
#  | Processing data in channel 2...
#  | Time elapsed:  40.006694199 sec
# 0.8101988389356675
# 0.02321864832077077

# %%
Plt.PltTime(Time=ch5.TimeStamp,
            Data=[ch5.Max,ch6.Max,ChargeCollection3*100],
            Legend=['Anode','Cathode','Charge Collection [\%]'],
            Label='Amplitude [mV]',
            XTicks=XTicks3,
            YTicks=10,
            YRange=[0,200],
            SaveName='amp_ratio',
            Title='Charge Collection in Argon gas with Inner Chamber Closed at 100 V/cm',
            Save=False)
# plt.savefig('amp.pdf', bbox_inches='tight')

# %%
Plt.PltTime(Time=ch5.TimeStamp,
        Data=[ch5.GradTime,ch6.GradTime,ch5.GradTime - ch6.GradTime],
        Legend=['Anode','Cathode','Drift Time [$\mu$s]'],
        Label='Peak Time [$\mu$s]',
        XTicks=XTicks3,
        YTicks=10,
        YRange=[0,50],
        SaveName='drift_time',
        Save=False)

# %%
avg3 = np.mean(ChargeCollection3)
err3 = np.std(ChargeCollection3)/np.sqrt(len(ChargeCollection3))

fig = plt.figure(figsize=(8,6))
plt.xlim(0.5,1.5)
plt.hist(ChargeCollection3, bins=np.linspace(0.5,1.5,101), histtype='step', align='mid', lw=2)
plt.xlabel('Charge Collection', fontsize=16)
plt.ylabel('Counts/bin', fontsize=16)
plt.axvline(avg3, color='red')
plt.title('Charge Collection = %.4f ± %.4f' % (avg3,err3))
rectangle = plt.Rectangle((avg3-err3,0), 2*err3, 10000, fc='red',ec="red", alpha=0.2, fill=True)
plt.gca().add_patch(rectangle)
plt.savefig('chargecollection_hist.pdf',bbox_inches='tight')

# %%
Plt.PltWfm(Time=ch5.Time,
           Data=list(ch5.AmpClean[:100]),
           Legend=['Anode'],
           XTicks=100,
           YTicks=20,
           SaveName='avg_waveform',
           Color='k')

Plt.PltWfm(Time=ch6.Time,
           Data=list(ch6.AmpClean[:100]),
           Legend=['Cathode'],
           XTicks=100,
           YTicks=20,
           SaveName='avg_waveform',
           Color='k')

# %%
FilePath = '/project/fas/david_moore/zl423/PurityData/20200910/'
Files4 = sorted(glob.glob(FilePath+'GAr*BetterNoise*'))
arg4 = Namespace(filepath=Files4, dirpath=None, txt=False, show=True)
for ii,File in enumerate(Files4): 
    print(ii, File)
    
ch7 = Wvf.WFM(ID=1, Pol=1)
ch8 = Wvf.WFM(ID=2, Pol=-1)
channels4 = [ch7, ch8]

FileNames4, Method = An.ChooseFilesToAnalyze(arg4)
for File in FileNames4: 
    An.ImportDataFromHDF5(File, channels4)

An.DoAnalysis(channels4)

ChargeCollection4 = ch7.Max / ch8.Max
DiffMinute4 = int((np.max(ch7.TimeStamp) - np.min(ch7.TimeStamp)).seconds/60.0 + 0.5)
XTicks4 = int((DiffMinute4/12.0 + 0.5))+1
print(np.mean(ChargeCollection4))
print(np.std(ChargeCollection4)/np.sqrt(len(ChargeCollection4)))
# Out:
# 0 /project/fas/david_moore/zl423/PurityData/20200910/GAr_InnerChamberClosed_BetterNoise_Au-Thorslabs_10cm_C-500V_A-500V_1.h5
# 1 /project/fas/david_moore/zl423/PurityData/20200910/GAr_InnerChamberClosed_BetterNoise_Au-Thorslabs_10cm_C-500V_A-500V_2.h5
# 2 /project/fas/david_moore/zl423/PurityData/20200910/GAr_InnerChamberClosed_BetterNoise_Au-Thorslabs_10cm_C-500V_A-500V_3.h5
# 3 /project/fas/david_moore/zl423/PurityData/20200910/GAr_InnerChamberClosed_BetterNoise_Au-Thorslabs_10cm_C-500V_A-500V_4.h5
# 4 /project/fas/david_moore/zl423/PurityData/20200910/GAr_InnerChamberClosed_BetterNoise_HeaterON_Au-Thorslabs_10cm_C-500V_A-500V_1.h5
# 5 /project/fas/david_moore/zl423/PurityData/20200910/GAr_InnerChamberClosed_BetterNoise_HeaterON_Au-Thorslabs_10cm_C-500V_A-500V_2.h5
# 6 /project/fas/david_moore/zl423/PurityData/20200910/GAr_InnerChamberClosed_BetterNoise_HeaterON_Au-Thorslabs_10cm_C-500V_A-500V_3.h5
# 7 /project/fas/david_moore/zl423/PurityData/20200910/GAr_InnerChamberClosed_BetterNoise_HeaterON_Purify_Au-Thorslabs_10cm_C-500V_A-500V_1.h5
# 8 /project/fas/david_moore/zl423/PurityData/20200910/GAr_InnerChamberClosed_BetterNoise_HeaterON_Purify_Au-Thorslabs_10cm_C-500V_A-500V_2.h5
# 9 /project/fas/david_moore/zl423/PurityData/20200910/GAr_InnerChamberClosed_BetterNoise_HeaterON_Purify_Au-Thorslabs_10cm_C-500V_A-500V_3.h5
# 10 /project/fas/david_moore/zl423/PurityData/20200910/GAr_InnerChamberClosed_BetterNoise_HeaterON_Purify_Au-Thorslabs_10cm_C-500V_A-500V_4.h5
#  | Filename... /project/fas/david_moore/zl423/PurityData/20200910/GAr_InnerChamberClosed_BetterNoise_Au-Thorslabs_10cm_C-500V_A-500V_1.h5
#  | Number of files in ch1...	 11/11
#  | Number of files in ch2...	 11/11
#  | Filename... /project/fas/david_moore/zl423/PurityData/20200910/GAr_InnerChamberClosed_BetterNoise_Au-Thorslabs_10cm_C-500V_A-500V_2.h5
#  | Number of files in ch1...	 42/53
#  | Number of files in ch2...	 42/53
#  | Filename... /project/fas/david_moore/zl423/PurityData/20200910/GAr_InnerChamberClosed_BetterNoise_Au-Thorslabs_10cm_C-500V_A-500V_3.h5
#  | Number of files in ch1...	 30/83
#  | Number of files in ch2...	 30/83
#  | Filename... /project/fas/david_moore/zl423/PurityData/20200910/GAr_InnerChamberClosed_BetterNoise_Au-Thorslabs_10cm_C-500V_A-500V_4.h5
#  | Number of files in ch1...	 35/118
#  | Number of files in ch2...	 35/118
#  | Filename... /project/fas/david_moore/zl423/PurityData/20200910/GAr_InnerChamberClosed_BetterNoise_HeaterON_Au-Thorslabs_10cm_C-500V_A-500V_1.h5
#  | Number of files in ch1...	 21/139
#  | Number of files in ch2...	 21/139
#  | Filename... /project/fas/david_moore/zl423/PurityData/20200910/GAr_InnerChamberClosed_BetterNoise_HeaterON_Au-Thorslabs_10cm_C-500V_A-500V_2.h5
#  | Number of files in ch1...	 30/169
#  | Number of files in ch2...	 30/169
#  | Filename... /project/fas/david_moore/zl423/PurityData/20200910/GAr_InnerChamberClosed_BetterNoise_HeaterON_Au-Thorslabs_10cm_C-500V_A-500V_3.h5
#  | Number of files in ch1...	 45/214
#  | Number of files in ch2...	 45/214
#  | Filename... /project/fas/david_moore/zl423/PurityData/20200910/GAr_InnerChamberClosed_BetterNoise_HeaterON_Purify_Au-Thorslabs_10cm_C-500V_A-500V_1.h5
#  | Number of files in ch1...	 16/230
#  | Number of files in ch2...	 16/230
#  | Filename... /project/fas/david_moore/zl423/PurityData/20200910/GAr_InnerChamberClosed_BetterNoise_HeaterON_Purify_Au-Thorslabs_10cm_C-500V_A-500V_2.h5
#  | Number of files in ch1...	 18/248
#  | Number of files in ch2...	 18/248
#  | Filename... /project/fas/david_moore/zl423/PurityData/20200910/GAr_InnerChamberClosed_BetterNoise_HeaterON_Purify_Au-Thorslabs_10cm_C-500V_A-500V_3.h5
#  | Number of files in ch1...	 25/273
#  | Number of files in ch2...	 25/273
#  | Filename... /project/fas/david_moore/zl423/PurityData/20200910/GAr_InnerChamberClosed_BetterNoise_HeaterON_Purify_Au-Thorslabs_10cm_C-500V_A-500V_4.h5
#  | Number of files in ch1...	 40/313
#  | Number of files in ch2...	 40/313
#  | Processing data in channel 1...
#  | Processing data in channel 2...
#  | Time elapsed:  59.093469661 sec
# 0.5184347789328646
# 0.005801935624017943

# %%
Plt.PltTime(Time=ch7.TimeStamp,
            Data=[ch7.Max,ch8.Max,ChargeCollection4*100],
            Legend=['Anode','Cathode','Charge Collection [\%]'],
            Label='Amplitude [mV]',
            XTicks=XTicks4,
            YTicks=10,
            YRange=[0,120],
            SaveName='amp_ratio',
            Title='Charge Collection in Argon gas with Inner Chamber Closed and Better Noise at 100 V/cm',
            Save=False)
# plt.savefig('amp.pdf', bbox_inches='tight')

# %%
avg4 = np.mean(ChargeCollection4)
err4 = np.std(ChargeCollection4)/np.sqrt(len(ChargeCollection4))

fig = plt.figure(figsize=(8,6))
plt.xlim(0.0,2.0)
plt.hist(ChargeCollection4, bins=np.linspace(0.0,2.0,201), histtype='step', align='mid', lw=2)
plt.xlabel('Charge Collection', fontsize=16)
plt.ylabel('Counts/bin', fontsize=16)
plt.axvline(avg4, color='red')
plt.title('Charge Collection = %.4f ± %.4f' % (avg4,err4))
rectangle = plt.Rectangle((avg4-err4,0), 2*err4, 10000, fc='red',ec="red", alpha=0.2, fill=True)
plt.gca().add_patch(rectangle)
plt.savefig('chargecollection_hist.pdf',bbox_inches='tight')

# %%
Plt.PltWfm(Time=ch7.Time,
           Data=list(ch7.AmpClean),
           Legend=['Anode'],
           XTicks=100,
           YTicks=10,
           SaveName='avg_waveform',
           Color='k')

Plt.PltWfm(Time=ch8.Time,
           Data=list(ch8.AmpClean),
           Legend=['Cathode'],
           XTicks=100,
           YTicks=20,
           SaveName='avg_waveform',
           Color='k')

# %%
Plt.PltTime(Time=ch7.TimeStamp,
        Data=[ch7.GradTime,ch8.GradTime,ch7.GradTime - ch8.GradTime],
        Legend=['Anode','Cathode','Drift Time [$\mu$s]'],
        Label='Peak Time [$\mu$s]',
        XTicks=XTicks4,
        YTicks=10,
        YRange=[0,50],
        SaveName='drift_time',
        Save=False)

# %%
print(r'Drift velocity corresponds to %.2fmm/µs for this 10cm drift length and drift time of %.2fµs ' 
      % (100.0/np.mean(ch7.GradTime - ch8.GradTime), np.mean(ch7.GradTime - ch8.GradTime)))
# Out:
# Drift velocity corresponds to 4.35mm/µs for this 10cm drift length and drift time of 22.98µs
