# %% [markdown]
# # Import and Setup

# %% [markdown]
# Adjust cell width to view more content

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
# Out:
# <style>.container { width:95% !important; }</style>

# %% [markdown]
# Import general packages and YLXPS-related packages

# %%
import numpy as np
import matplotlib.pyplot as plt
import sys 
import os 
import scipy
import importlib
import datetime as dt
import pandas as pd

plt.style.use('../style.mplstyle')
colors = plt.rcParams['axes.prop_cycle'].by_key()['color']

sys.path.insert(0, '../../purity-monitor/')
sys.path.insert(0, '../analysis/')
import HelperClasses as Dataset
import StandMonitor as Monitor
import PlotFunctions as Plt
# Out:
# ../analysis\HelperClasses.py:122: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if ii+1 is not Channel and Channel is not -1:

# %%
importlib.reload(Dataset)
importlib.reload(Monitor)
importlib.reload(Plt)
# Out:
# <module 'PlotFunctions' from '../analysis\\PlotFunctions.py'>

# %% [markdown]
# # Data Read-In

# %%
D1 = Dataset.Dataset(Path='C:/Data/20210317/', Selection='*')
D1.RunStandardAnalysis()
D1.ShowAmplitudeVsTime(YTicks=100, YMax=1000)
plt.savefig("20210317_amp.pdf")
# Out:
#  | Filename... C:/Data/20210317\Vacuum_Au-Thorslabs_C-20V_A-250V_1.h5
#  | Number of files in ch1...	 61/61
#  | Number of files in ch2...	 61/61
#  | Filename... C:/Data/20210317\Vacuum_Au-Thorslabs_C-40V_A-500V_1.h5
#  | Number of files in ch1...	 133/194
#  | Number of files in ch2...	 133/194
#  | Processing data in channel 1...
#  | Processing data in channel 2...
#  | Time elapsed:  12.5625 sec
# 156
# 175
