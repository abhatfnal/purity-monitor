# %% [markdown]
# # Import and Setup

# %% [markdown]
# Adjust cell width to view more content

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %% [markdown]
# Import general packages and YLXPS-related packages

# %%
import numpy as np
import matplotlib.pyplot as plt
import sys 
import os 
import scipy
import importlib

sys.path.insert(0, '/gpfs/loomis/project/david_moore/aj487/purity_monitor/')
sys.path.insert(0, '/gpfs/loomis/project/david_moore/aj487/purity_monitor/analysis/')
import HelperClasses as Dataset
import StandMonitor as Monitor
import PlotFunctions as Plt

# %% [markdown]
# # Data Read-In

# %%
D1 = Dataset.Dataset(Path='/project/fas/david_moore/aj487/Data_WL110/LXe_Setup/TPC/20201216/', Selection='*')
D1.RunStandardAnalysis()
D1.ShowAmplitudeVsTime()
D1.ShowBaselineNoise()
# Out:
#  | Filename... /project/fas/david_moore/aj487/Data_WL110/LXe_Setup/TPC/20201216/Vacuum_Au-Thorslabs_C-50V_A-1500V_1.h5
#  | Number of files in ch1...	 142/142
#  | Number of files in ch2...	 142/142
#  | Processing data in channel 1...
#  | Processing data in channel 2...
#  | Time elapsed:  5.073984452 sec
# Ticks:  100

# %%
D2 = Dataset.Dataset(Path='/project/fas/david_moore/aj487/Data_WL110/LXe_Setup/TPC/20201218/', Selection='*-170*')
D2.RunStandardAnalysis()
D2.ShowAmplitudeVsTime(YTicks=10)
D2.ShowDrifttimeVsTime()
D2.ShowBaselineNoise()
Plt.PltWfm(Time=D2.Ch[0].Time,
           Data=[np.mean(D2.Ch[0].AmpClean, axis=0), np.mean(D2.Ch[1].AmpClean, axis=0)/-1.0],
           Legend=['Anode'],
           XTicks=100,
           YTicks=2,
           SaveName='avg_waveform',
           Color='k')
plt.ylim(-10,20)
plt.xlim(-100,500)
# Out:
#  | Filename... /project/fas/david_moore/aj487/Data_WL110/LXe_Setup/TPC/20201218/XeGas_Au-Thorslabs_C-170V_A-3000V_1.h5
#  | Number of files in ch1...	 584/584
#  | Number of files in ch2...	 584/584
#  | Filename... /project/fas/david_moore/aj487/Data_WL110/LXe_Setup/TPC/20201218/XeGas_Au-Thorslabs_C-170V_A-3000V_2.h5
#  | Number of files in ch1...	 132/716
#  | Number of files in ch2...	 132/716
#  | Filename... /project/fas/david_moore/aj487/Data_WL110/LXe_Setup/TPC/20201218/XeGas_Au-Thorslabs_C-170V_A-3000V_noSRS_1.h5
#  | Number of files in ch1...	 21/737
#  | Number of files in ch2...	 21/737
#  | Processing data in channel 1...
#  | Processing data in channel 2...
#  | Time elapsed:  22.416245812 sec
# Ticks:  10
# (-100, 500)

# %%
D3 = Dataset.Dataset(Path='/project/fas/david_moore/aj487/Data_WL110/LXe_Setup/TPC/20201218/', Selection='*noSRS*')
D3.RunStandardAnalysis()
D3.ShowAmplitudeVsTime(YTicks=5)
D3.ShowDrifttimeVsTime()
D3.ShowBaselineNoise()
Plt.PltWfm(Time=D3.Ch[0].Time,
           Data=[np.mean(D3.Ch[0].AmpClean, axis=0), np.mean(D3.Ch[1].AmpClean, axis=0)*-1],
           Legend=['Anode'],
           XTicks=100,
           YTicks=2,
           SaveName='avg_waveform',
           Color='k')
plt.ylim(-5,5)
plt.xlim(-100,500)
print(np.mean(D3.Ch[0].GradTime - D3.Ch[1].GradTime))
print(np.median(D3.Ch[0].GradTime - D3.Ch[1].GradTime))
# Out:
#  | Filename... /project/fas/david_moore/aj487/Data_WL110/LXe_Setup/TPC/20201218/XeGas_Au-Thorslabs_C-170V_A-3000V_noSRS_2.h5
#  | Number of files in ch1...	 39/39
#  | Number of files in ch2...	 39/39
#  | Filename... /project/fas/david_moore/aj487/Data_WL110/LXe_Setup/TPC/20201218/XeGas_Au-Thorslabs_C-170V_A-3000V_noSRS_3.h5
#  | Number of files in ch1...	 72/111
#  | Number of files in ch2...	 72/111
#  | Filename... /project/fas/david_moore/aj487/Data_WL110/LXe_Setup/TPC/20201218/XeGas_Au-Thorslabs_C-170V_A-3000V_noSRS_1.h5
#  | Number of files in ch1...	 21/132
#  | Number of files in ch2...	 21/132
#  | Processing data in channel 1...
#  | Processing data in channel 2...
#  | Time elapsed:  49.767005741 sec
# Ticks:  5
# 66.55790909090909
# 65.5368

# %%
driftfield = [200,]
velocity = 100/np.array([66.5])
