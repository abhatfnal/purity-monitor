# %% [markdown]
# # Import and Setup

# %% [markdown]
# Adjust cell width to view more content

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
# Out:
# <style>.container { width:95% !important; }</style>

# %% [markdown]
# Import general packages and YLXPS-related packages

# %%
import numpy as np
import matplotlib.pyplot as plt
import sys 
import os 
import scipy
import importlib

sys.path.insert(0, '../../purity-monitor/')
sys.path.insert(0, '../analysis/')
import HelperClasses as Dataset
import StandMonitor as Monitor
import PlotFunctions as Plt

# %% [markdown]
# # Data Read-In

# %%
D1 = Dataset.Dataset(Path='C:/Data/20210208/', Selection='*Thorslabs_C*')
D1.RunStandardAnalysis()
D1.ShowAmplitudeVsTime(YTicks=10, YMax=120)
D1.ShowBaselineNoise()
# Out:
#  | Filename... C:/Data/20210208\XenonGas_Au-Thorslabs_C-100V_A-1300V_1.h5
#  | Number of files in ch1...	 161/161
#  | Number of files in ch2...	 161/161
#  | Filename... C:/Data/20210208\XenonGas_Au-Thorslabs_C-80V_A-1000V_1.h5
#  | Number of files in ch1...	 31/192
#  | Number of files in ch2...	 31/192
#  | Processing data in channel 1...
#  | Processing data in channel 2...
#  | Time elapsed:  7.734375 sec
# Ticks:  10

# %%
plt.scatter(D1.Ch[0].TimeStamp, D1.Ch[0].BaseStd)
plt.scatter(D1.Ch[1].TimeStamp, D1.Ch[1].BaseStd)

# %%
Plt.PltWfm(Time=D1.Ch[0].Time,
           Data=D1.Ch[0].AmpClean[D1.InverseCut],
           Legend=['Anode'],
           XTicks=100,
           YTicks=10,
           SaveName='avg_waveform',
           Color='k')
plt.show()

# %%
D2 = Dataset.Dataset(Path='C:/Data/20210208/', Selection='*Average*')
D2.RunStandardAnalysis()
D2.ShowAmplitudeVsTime(YTicks=10, YMax=120)
D2.ShowBaselineNoise()
# Out:
#  | Filename... C:/Data/20210208\XenonGas_Au-Thorslabs_NoAverage_C-150V_A-2000V_1.h5
#  | Number of files in ch1...	 52/52
#  | Number of files in ch2...	 52/52
#  | Filename... C:/Data/20210208\XenonGas_Au-Thorslabs_NoAverage_C-150V_A-2000V_2.h5
#  | Number of files in ch1...	 18/70
#  | Number of files in ch2...	 18/70
#  | Processing data in channel 1...
#  | Processing data in channel 2...
#  | Time elapsed:  15.84375 sec
# Ticks:  10

# %%
plt.scatter(D2.Ch[0].TimeStamp, D2.Ch[0].BaseStd)
plt.scatter(D2.Ch[1].TimeStamp, D2.Ch[1].BaseStd)
plt.ylim(0,50)
# Out:
# (0.0, 50.0)
