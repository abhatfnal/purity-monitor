# %% [markdown]
# # Import and Setup

# %% [markdown]
# Adjust cell width to view more content

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
# Out:
# <style>.container { width:95% !important; }</style>

# %% [markdown]
# Import general packages and YLXPS-related packages

# %%
import numpy as np
import matplotlib.pyplot as plt
import sys 
import os 
import scipy
import importlib

sys.path.insert(0, '../../purity-monitor/')
sys.path.insert(0, '../analysis/')
import HelperClasses as Dataset
import StandMonitor as Monitor
import PlotFunctions as Plt

# %% [markdown]
# # Data Read-In

# %%
D1 = Dataset.Dataset(Path='C:/Data/20210204/', Selection='*Vacuum*')
D1.RunStandardAnalysis()
D1.ShowAmplitudeVsTime(YTicks=500, YMax=5000)
# Out:
#  | Filename... C:/Data/20210204\Vacuum_Au-Thorslabs_C-15V_A-200V_1.h5
#  | Number of files in ch1...	 25/25
#  | Number of files in ch2...	 25/25
#  | Processing data in channel 1...
#  | Processing data in channel 2...
#  | Time elapsed:  3.046875 sec
# Ticks:  500

# %%
D3 = Dataset.Dataset(Path='C:/Data/20210204/', Selection='*XenonGas_SwapAmp*')
D3.RunStandardAnalysis()
D3.ShowAmplitudeVsTime(YTicks=10, YMax=150)
# Out:
#  | Filename... C:/Data/20210204\XenonGas_SwapAmp_Au-Thorslabs_C-100V_A-1300V_1.h5
#  | Number of files in ch1...	 22/22
#  | Number of files in ch2...	 22/22
#  | Filename... C:/Data/20210204\XenonGas_SwapAmp_Au-Thorslabs_C-150V_A-2000V_1.h5
#  | Number of files in ch1...	 25/47
#  | Number of files in ch2...	 25/47
#  | Processing data in channel 1...
#  | Processing data in channel 2...
#  | Time elapsed:  4.75 sec
# Ticks:  10

# %%
D2 = Dataset.Dataset(Path='C:/Data/20210204/', Selection='*XenonGas_Au*')
D2.RunStandardAnalysis()
D2.ShowAmplitudeVsTime(YTicks=10, YMax=150)
D2.ShowDrifttimeVsTime()
# Out:
#  | Filename... C:/Data/20210204\XenonGas_Au-Thorslabs_C-100V_A-1300V_1.h5
#  | Number of files in ch1...	 20/20
#  | Number of files in ch2...	 20/20
#  | Filename... C:/Data/20210204\XenonGas_Au-Thorslabs_C-150V_A-2000V_1.h5
#  | Number of files in ch1...	 25/45
#  | Number of files in ch2...	 25/45
#  | Processing data in channel 1...
#  | Processing data in channel 2...
#  | Time elapsed:  6.328125 sec
# Ticks:  10

# %%
Plt.PltWfm(Time=D2.Ch[0].Time,
           Data=[np.mean(D2.Ch[0].AmpClean[D2.Cut], axis=0),np.mean(D2.Ch[1].AmpClean[D2.Cut]*-1, axis=0)] ,
           Legend=['Anode'],
           XTicks=100,
           YTicks=5,
           SaveName='avg_waveform',
           Color='k')
plt.xlim(0,200)
plt.ylim(-30,30)
plt.show()
