# %% [markdown]
# # Import and Setup

# %% [markdown]
# Adjust cell width to view more content

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
# Out:
# <style>.container { width:95% !important; }</style>

# %% [markdown]
# Import general packages and YLXPS-related packages

# %%
import numpy as np
import matplotlib.pyplot as plt
import sys 
import os 
import scipy
import importlib
import datetime as dt
import pandas as pd

plt.style.use('../style.mplstyle')
colors = plt.rcParams['axes.prop_cycle'].by_key()['color']

sys.path.insert(0, '../../purity-monitor/')
sys.path.insert(0, '../analysis/')
import HelperClasses as Dataset
import StandMonitor as Monitor
import PlotFunctions as Plt

# %%
importlib.reload(Dataset)
importlib.reload(Monitor)
importlib.reload(Plt)
# Out:
# <module 'PlotFunctions' from '../analysis\\PlotFunctions.py'>

# %% [markdown]
# # Data Read-In

# %%
D1 = Dataset.Dataset(Path='C:/Data/20210319/', Selection='*C-90V*')
D1.RunStandardAnalysis()
D1.ShowAmplitudeVsTime(YTicks=2, YMax=20)
# D1.ShowDrifttimeVsTime()
# Out:
#  | Filename... C:/Data/20210319\XeGas_Au-Thorslabs_C-90V_A-1000V_1.h5
#  | Number of files in ch1...	 8/8
#  | Number of files in ch2...	 8/8
#  | Processing data in channel 1...
# [-3.37069784 -3.36392979 -3.35459688 -3.34278206 -3.32855672 -3.31208907
#  -3.29359885 -3.27319223 -3.2510029  -3.22729534 -3.20230711 -3.17619215
#  -3.14904478 -3.1209025  -3.0918351  -3.06201068 -3.03160605 -3.00079315
#  -2.96982703 -2.93900122 -2.90855375 -2.87864614 -2.84941303 -2.82099213
#  -2.79346872 -2.76688491 -2.74129221 -2.71675058 -2.69339264 -2.67140845
#  -2.65088327 -2.63183207 -2.61430199 -2.59831487 -2.58392725 -2.57131009
#  -2.56059957 -2.55177945 -2.54474619 -2.53944143 -2.53590299 -2.53414051
#  -2.53403186 -2.53540103 -2.53813051 -2.54219389 -2.54762906 -2.55447463
#  -2.56275374 -2.57255275 -2.58404209 -2.59738771 -2.61271725 -2.63009262
#  -2.64944443 -2.67065678 -2.69367172 -2.71842296 -2.74482955 -2.77287309
# ...

# %%
Plt.PltWfm(Time=D1.Ch[0].Time,
           Data=[np.mean(D1.Ch[0].AmpClean[D1.Cut], axis=0), np.mean(D1.Ch[1].AmpClean[D1.Cut], axis=0)*-1],
           Legend=['Anode'],
           XTicks=100,
           YTicks=10,
           SaveName='avg_waveform',
           Color='k')
plt.ylim(-10,10)
# Out:
# (-10.0, 10.0)
