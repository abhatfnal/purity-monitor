# %% [markdown]
# # Import and Setup

# %%
import numpy as np
import matplotlib.pyplot as plt
import sys 
import importlib

plt.style.use('../../style.mplstyle')
colors = plt.rcParams['axes.prop_cycle'].by_key()['color']

sys.path.insert(0, '../../../purity-monitor/')
sys.path.insert(0, '../../analysis/')
import HelperClasses as Dataset
import StandMonitor as Monitor
import PlotFunctions as Plt

# %%
importlib.reload(Dataset)
importlib.reload(Monitor)
importlib.reload(Plt)
# Out:
# <module 'PlotFunctions' from '../../analysis\\PlotFunctions.py'>

# %% [markdown]
# # Data Read-In

# %%
D1 = Dataset.Dataset(Path='C:/Data/20210507/', Selection='Vacuum*')
D1.RunStandardAnalysis()
D1.ShowAmplitudeVsTime(YTicks=200, YMax=1000)
plt.savefig('20210507_cc.png')

plt.figure()
plt.xlabel('Time [us]')
plt.ylabel('Amplitude [mV]')
plt.plot(D1.Ch[0].Time, np.mean(D1.Ch[0].Amp,axis=0))
plt.plot(D1.Ch[0].Time, np.mean(D1.Ch[1].Amp,axis=0))
plt.xlim(-100,1000)
plt.savefig('20210507_wfm.png')
# Out:
#  | Filename... C:/Data/20210507\Vacuum_C-80V_A-500V_0.h5
#  | Number of files in ch1...	 100/100
#  | Number of files in ch2...	 100/100
#  | Filename... C:/Data/20210507\Vacuum_C-80V_A-500V_1.h5
#  | Number of files in ch1...	 100/200
#  | Number of files in ch2...	 100/200
#  | Filename... C:/Data/20210507\Vacuum_C-80V_A-500V_1_0.h5
#  | Number of files in ch1...	 100/300
#  | Number of files in ch2...	 100/300
#  | Filename... C:/Data/20210507\Vacuum_C-80V_A-500V_2.h5
#  | Number of files in ch1...	 56/356
#  | Number of files in ch2...	 56/356
#  | Processing data in channel 1...
#  | Processing data in channel 2...
#  | Time elapsed:  25.671875 sec

# %%
D2 = Dataset.Dataset(Path='C:/Data/20210507/', Selection='XeGas*')
D2.RunStandardAnalysis()
D2.ShowAmplitudeVsTime(YTicks=5, YMax=30)
# plt.savefig('20210507_cc.png')

plt.figure()
plt.xlabel('Time [us]')
plt.ylabel('Amplitude [mV]')
plt.plot(D2.Ch[0].Time, np.mean(D2.Ch[0].Amp,axis=0))
plt.plot(D2.Ch[0].Time, np.mean(D2.Ch[1].Amp,axis=0))
plt.xlim(-100,200)
# plt.savefig('20210507_wfm.png')
# Out:
#  | Filename... C:/Data/20210507\XeGas_C-200V_A-1200V_0.h5
#  | Number of files in ch1...	 58/58
#  | Number of files in ch2...	 58/58
#  | Processing data in channel 1...
#  | Processing data in channel 2...
#  | Time elapsed:  35.578125 sec
# (-100.0, 200.0)
