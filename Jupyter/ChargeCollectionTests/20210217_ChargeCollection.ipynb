# %% [markdown]
# # Import and Setup

# %% [markdown]
# Adjust cell width to view more content

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
# Out:
# <style>.container { width:95% !important; }</style>

# %% [markdown]
# Import general packages and YLXPS-related packages

# %%
import numpy as np
import matplotlib.pyplot as plt
import sys 
import os 
import scipy
import importlib

sys.path.insert(0, '../../purity-monitor/')
sys.path.insert(0, '../analysis/')
import HelperClasses as Dataset
import StandMonitor as Monitor
import PlotFunctions as Plt

# %% [markdown]
# # Data Read-In

# %%
# D1 = Dataset.Dataset(Path='C:/Data/20210217/', Selection='*Vacuum*')
# D1.RunStandardAnalysis()
# D1.ShowAmplitudeVsTime(YTicks=50, YMax=200)
# D1.ShowBaselineNoise(BinMax=10)

# %%
# Plt.PltWfm(Time=D1.Ch[0].Time,
#            Data=D1.Ch[0].AmpClean[D1.Cut],
#            Legend=['Anode'],
#            XTicks=100,
#            YTicks=10,
#            SaveName='avg_waveform',
#            Color='k')
# Plt.PltWfm(Time=D1.Ch[1].Time,
#            Data=D1.Ch[1].AmpClean[D1.Cut]*-1,
#            Legend=['Anode'],
#            XTicks=100,
#            YTicks=10,
#            SaveName='avg_waveform',
#            Color='k')
# plt.show()

# %%
# D2 = Dataset.Dataset(Path='C:/Data/20210217/', Selection='*GXe_Au-Thorslabs_C*')
# D2.RunStandardAnalysis()
# D2.ShowAmplitudeVsTime(YTicks=10, YMax=120)
# # D2.ShowBaselineNoise(BinMax=10)
# D2.ShowDrifttimeVsTime()

# %%
# Plt.PltWfm(Time=D2.Ch[0].Time,
#            Data=[np.mean(D2.Ch[0].AmpClean[D2.Cut], axis=0),np.mean(D2.Ch[1].AmpClean[D2.Cut]*-1, axis=0)] ,
#            Legend=['Anode'],
#            XTicks=100,
#            YTicks=5,
#            SaveName='avg_waveform',
#            Color='k')
# plt.xlim(-100,100)
# plt.show()

# %%
D3 = Dataset.Dataset(Path='C:/Data/20210218/', Selection='*GXe_Au-Thorslabs_C-300*')
D3.RunStandardAnalysis()
D3.ShowAmplitudeVsTime(YTicks=10, YMax=150)
D3.ShowBaselineNoise(BinMax=20)
print(np.mean(D3.Ch[0].DriftTime-D3.Ch[1].DriftTime))
D3.ShowDrifttimeVsTime()
# Out:
#  | Filename... C:/Data/20210218\GXe_Au-Thorslabs_C-300V_A-2000V_1.h5
#  | Number of files in ch1...	 93/93
#  | Number of files in ch2...	 93/93
#  | Processing data in channel 1...
#  | Processing data in channel 2...
#  | Time elapsed:  4.015625 sec
# Ticks:  10
# 15.175638709677425

# %%
Plt.PltWfm(Time=D3.Ch[0].Time,
           Data=D3.Ch[1].AmpClean ,
           Legend=['Anode'],
           XTicks=100,
           YTicks=5,
           SaveName='avg_waveform',
           Color='k')
plt.xlim(-100,100)
plt.ylim(-20,20)
plt.show()

# %%
D4 = Dataset.Dataset(Path='C:/Data/20210218/', Selection='*GXe_DriftVelocity_Au-Thorslabs*')
D4.RunStandardAnalysis()
D4.ShowAmplitudeVsTime(YTicks=10, YMax=150)
D4.ShowBaselineNoise(BinMax=20)
print(np.mean(D4.Ch[0].DriftTime - D4.Ch[1].DriftTime))
D4.ShowDrifttimeVsTime()
# Out:
#  | Filename... C:/Data/20210218\GXe_DriftVelocity_Au-Thorslabs_C-100V_A-600V_1.h5
#  | Number of files in ch1...	 33/33
#  | Number of files in ch2...	 33/33
#  | Filename... C:/Data/20210218\GXe_DriftVelocity_Au-Thorslabs_C-200V_A-1200V_1.h5
#  | Number of files in ch1...	 63/96
#  | Number of files in ch2...	 63/96
#  | Filename... C:/Data/20210218\GXe_DriftVelocity_Au-Thorslabs_C-300V_A-1800V_1.h5
#  | Number of files in ch1...	 109/205
#  | Number of files in ch2...	 109/205
#  | Filename... C:/Data/20210218\GXe_DriftVelocity_Au-Thorslabs_C-50V_A-300V_1.h5
#  | Number of files in ch1...	 38/243
#  | Number of files in ch2...	 38/243
#  | Filename... C:/Data/20210218\GXe_DriftVelocity_Au-Thorslabs_C-65V_A-400V_1.h5
#  | Number of files in ch1...	 34/277
#  | Number of files in ch2...	 34/277
#  | Processing data in channel 1...
#  | Processing data in channel 2...
#  | Time elapsed:  31.828125 sec
# Ticks:  10
# 17.398249819494602

# %%
Plt.PltWfm(Time=D4.Ch[0].Time,
           Data=D4.Ch[1].AmpClean ,
           Legend=['Anode'],
           XTicks=100,
           YTicks=5,
           SaveName='avg_waveform',
           Color='k')
plt.xlim(-100,100)
plt.ylim(-20,20)
plt.show()

Plt.PltWfm(Time=D4.Ch[0].Time,
           Data=D4.Ch[0].AmpClean ,
           Legend=['Anode'],
           XTicks=100,
           YTicks=5,
           SaveName='avg_waveform',
           Color='k')
plt.xlim(-100,100)
plt.ylim(-20,20)
plt.show()
