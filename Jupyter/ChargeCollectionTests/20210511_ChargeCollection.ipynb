# %% [markdown]
# # Import and Setup

# %%
import numpy as np
import matplotlib.pyplot as plt
import sys 
import importlib

plt.style.use('../../style.mplstyle')
colors = plt.rcParams['axes.prop_cycle'].by_key()['color']

sys.path.insert(0, '../../../purity-monitor/')
sys.path.insert(0, '../../analysis/')
import HelperClasses as Dataset
import StandMonitor as Monitor
import PlotFunctions as Plt

# %%
importlib.reload(Dataset)
importlib.reload(Monitor)
importlib.reload(Plt)
# Out:
# <module 'PlotFunctions' from '../../analysis\\PlotFunctions.py'>

# %% [markdown]
# # Data Read-In

# %%
D1 = Dataset.Dataset(Path='C:/Data/20210511/', Selection='Vacuum*')
D1.RunStandardAnalysis()
D1.ShowAmplitudeVsTime(YTicks=20, YMax=200)

plt.figure()
plt.xlabel('Time [us]')
plt.ylabel('Amplitude [mV]')
plt.plot(D1.Ch[0].Time, np.mean(D1.Ch[0].Amp,axis=0))
plt.plot(D1.Ch[0].Time, np.mean(D1.Ch[1].Amp,axis=0))
plt.xlim(-100,1000)
# Out:
#  | Filename... C:/Data/20210511\Vacuum_C-200V_A-1200V_0.h5
#  | Number of files in ch1...	 100/100
#  | Number of files in ch2...	 100/100
#  | Filename... C:/Data/20210511\Vacuum_C-200V_A-1200V_1.h5
#  | Number of files in ch1...	 100/200
#  | Number of files in ch2...	 100/200
#  | Filename... C:/Data/20210511\Vacuum_C-200V_A-1200V_2.h5
#  | Number of files in ch1...	 100/300
#  | Number of files in ch2...	 100/300
#  | Filename... C:/Data/20210511\Vacuum_C-200V_A-1200V_3.h5
#  | Number of files in ch1...	 100/400
#  | Number of files in ch2...	 100/400
#  | Filename... C:/Data/20210511\Vacuum_C-200V_A-1200V_4.h5
#  | Number of files in ch1...	 100/500
#  | Number of files in ch2...	 100/500
#  | Filename... C:/Data/20210511\Vacuum_C-200V_A-1200V_5.h5
#  | Number of files in ch1...	 100/600
#  | Number of files in ch2...	 100/600
#  | Filename... C:/Data/20210511\Vacuum_C-200V_A-1200V_6.h5
#  | Number of files in ch1...	 67/667
#  | Number of files in ch2...	 67/667
# ...

# %%
D2 = Dataset.Dataset(Path='C:/Data/20210511/', Selection='XeGas*')
D2.RunStandardAnalysis()
D2.ShowAmplitudeVsTime(YTicks=10, YMax=100)
# plt.savefig('20210507_cc.png')

plt.figure()
plt.xlabel('Time [us]')
plt.ylabel('Amplitude [mV]')
plt.plot(D2.Ch[0].Time, np.mean(D2.Ch[0].Amp,axis=0) - np.mean(D3.Ch[0].Amp,axis=0))
plt.plot(D2.Ch[0].Time, (np.mean(D2.Ch[1].Amp,axis=0) - np.mean(D3.Ch[1].Amp,axis=0))*-1)
plt.xlim(-100,200)
# plt.savefig('20210507_wfm.png')
# Out:
#  | Filename... C:/Data/20210511\XeGas_C-200V_A-1200V_0.h5
#  | Number of files in ch1...	 82/82
#  | Number of files in ch2...	 82/82
#  | Processing data in channel 1...
#  | Processing data in channel 2...
#  | Time elapsed:  42.015625 sec
# (-100.0, 200.0)

# %%
D3 = Dataset.Dataset(Path='C:/Data/20210511/', Selection='Noise*')
D3.RunStandardAnalysis()
D3.ShowAmplitudeVsTime(YTicks=10, YMax=100)
# plt.savefig('20210507_cc.png')

plt.figure()
plt.xlabel('Time [us]')
plt.ylabel('Amplitude [mV]')
plt.plot(D3.Ch[0].Time, np.mean(D3.Ch[0].Amp,axis=0))
plt.plot(D3.Ch[0].Time, np.mean(D3.Ch[1].Amp,axis=0))
plt.xlim(-100,200)
# plt.savefig('20210507_wfm.png')
# Out:
#  | Filename... C:/Data/20210511\Noise_XeGas_C-200V_A-1200V_0.h5
#  | Number of files in ch1...	 85/85
#  | Number of files in ch2...	 85/85
#  | Processing data in channel 1...
#  | Processing data in channel 2...
#  | Time elapsed:  40.5 sec
# (-100.0, 200.0)

# %%
D4 = Dataset.Dataset(Path='C:/Data/20210511/', Selection='Purify*')
D4.RunStandardAnalysis()
D4.ShowAmplitudeVsTime(YTicks=10, YMax=100)
# plt.savefig('20210507_cc.png')

plt.figure()
plt.xlabel('Time [us]')
plt.ylabel('Amplitude [mV]')
plt.plot(D4.Ch[0].Time, np.mean(D4.Ch[0].Amp,axis=0))
plt.plot(D4.Ch[0].Time, (np.mean(D4.Ch[1].Amp,axis=0))*-1)
plt.plot(D4.Ch[0].Time, np.mean(D4.Ch[0].Amp,axis=0) - np.mean(D3.Ch[0].Amp,axis=0))
plt.plot(D4.Ch[0].Time, (np.mean(D4.Ch[1].Amp,axis=0) - np.mean(D3.Ch[1].Amp,axis=0))*-1)
plt.xlim(-100,200)
# plt.savefig('20210507_wfm.png')
# Out:
#  | Filename... C:/Data/20210511\Purify_XeGas_C-200V_A-1200V_0.h5
#  | Number of files in ch1...	 66/66
#  | Number of files in ch2...	 66/66
#  | Filename... C:/Data/20210511\Purify_XeGas_C-200V_A-1200V_1_0.h5
#  | Number of files in ch1...	 100/166
#  | Number of files in ch2...	 100/166
#  | Filename... C:/Data/20210511\Purify_XeGas_C-200V_A-1200V_1_1.h5
#  | Number of files in ch1...	 100/266
#  | Number of files in ch2...	 100/266
#  | Filename... C:/Data/20210511\Purify_XeGas_C-200V_A-1200V_1_2.h5
#  | Number of files in ch1...	 49/315
#  | Number of files in ch2...	 49/315
#  | Filename... C:/Data/20210511\Purify_XeGas_C-200V_A-1200V_2_0.h5
#  | Number of files in ch1...	 100/415
#  | Number of files in ch2...	 100/415
#  | Filename... C:/Data/20210511\Purify_XeGas_C-200V_A-1200V_2_1.h5
#  | Number of files in ch1...	 77/492
#  | Number of files in ch2...	 77/492
#  | Processing data in channel 1...
#  | Processing data in channel 2...
#  | Time elapsed:  68.078125 sec
# ...
