# %% [markdown]
# # Import and Setup

# %% [markdown]
# Adjust cell width to view more content

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
# Out:
# <style>.container { width:95% !important; }</style>

# %% [markdown]
# Import general packages and YLXPS-related packages

# %%
import numpy as np
import matplotlib.pyplot as plt
import sys 
import os 
import scipy
import importlib
import datetime as dt
import pandas as pd

plt.style.use('../style.mplstyle')
colors = plt.rcParams['axes.prop_cycle'].by_key()['color']

sys.path.insert(0, '../../purity-monitor/')
sys.path.insert(0, '../analysis/')
import HelperClasses as Dataset
import StandMonitor as Monitor
import PlotFunctions as Plt

# %%
importlib.reload(Dataset)
importlib.reload(Monitor)
importlib.reload(Plt)
# Out:
# <module 'PlotFunctions' from '../analysis\\PlotFunctions.py'>

# %% [markdown]
# # Data Read-In

# %%
D1 = Dataset.Dataset(Path='C:/Data/20210305/', Selection='**')
D1.RunStandardAnalysis()
D1.ShowAmplitudeVsTime(YTicks=50, YMax=300)
plt.savefig("20210305_amp.pdf")
# Out:
#  | Filename... C:/Data/20210305\Vacuum_Au-Thorslabs_C-20V_A-120V_1.h5
#  | Number of files in ch1...	 312/312
#  | Number of files in ch2...	 312/312
#  | Filename... C:/Data/20210305\Vacuum_Au-Thorslabs_C-20V_A-120V_2.h5
#  | Number of files in ch1...	 113/425
#  | Number of files in ch2...	 113/425
#  | Filename... C:/Data/20210305\Vacuum_Au-Thorslabs_C-20V_A-120V_3.h5
#  | Number of files in ch1...	 1000/1425
#  | Number of files in ch2...	 1000/1425
#  | Processing data in channel 1...
#  | Processing data in channel 2...
#  | Time elapsed:  83.828125 sec
# Ticks:  50
# 1406
# 1425
