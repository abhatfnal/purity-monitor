# %% [markdown]
# # Import and Setup

# %% [markdown]
# Adjust cell width to view more content

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
# Out:
# <style>.container { width:95% !important; }</style>

# %% [markdown]
# Import general packages and YLXPS-related packages

# %%
import numpy as np
import matplotlib.pyplot as plt
import sys 
import os 
import scipy
import importlib
import datetime as dt
import pandas as pd

plt.style.use('../style.mplstyle')
colors = plt.rcParams['axes.prop_cycle'].by_key()['color']

sys.path.insert(0, '../../purity-monitor/')
sys.path.insert(0, '../analysis/')
import HelperClasses as Dataset
import StandMonitor as Monitor
import PlotFunctions as Plt

# %%
importlib.reload(Dataset)
importlib.reload(Monitor)
importlib.reload(Plt)
# Out:
# <module 'PlotFunctions' from '../analysis\\PlotFunctions.py'>

# %% [markdown]
# # Data Read-In

# %%
D1 = Dataset.Dataset(Path='C:/Data/20210314/', Selection='*Vacuum*')
D1.RunStandardAnalysis()
D1.ShowAmplitudeVsTime(YTicks=50, YMax=300)
# Out:
#  | Filename... C:/Data/20210314\Vacuum_Au-Thorslabs_C-20V_A-120V_1.h5
#  | Number of files in ch1...	 29/29
#  | Number of files in ch2...	 29/29
#  | Processing data in channel 1...
#  | Processing data in channel 2...
#  | Time elapsed:  2.796875 sec
# Ticks:  50
# 10
# 29

# %%
D1 = Dataset.Dataset(Path='C:/Data/20210314/', Selection='*XeGas*')
D1.RunStandardAnalysis()
D1.ShowAmplitudeVsTime(YTicks=5, YMax=50)
# Out:
#  | Filename... C:/Data/20210314\XeGas_Au-Thorslabs_C-170V_A-1000V_1.h5
#  | Number of files in ch1...	 7/7
#  | Number of files in ch2...	 7/7
#  | Filename... C:/Data/20210314\XeGas_Au-Thorslabs_C-170V_A-1000V_2.h5
#  | Number of files in ch1...	 31/38
#  | Number of files in ch2...	 31/38
#  | Filename... C:/Data/20210314\XeGas_Au-Thorslabs_C-200V_A-1200V_1.h5
#  | Number of files in ch1...	 86/124
#  | Number of files in ch2...	 86/124
#  | Processing data in channel 1...
#  | Processing data in channel 2...
#  | Time elapsed:  17.75 sec
# Ticks:  5
# 105
# 124
