# %% [markdown]
# # Import and Setup

# %% [markdown]
# Adjust cell width to view more content

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %% [markdown]
# Import general packages and YLXPS-related packages

# %%
import numpy as np
import matplotlib.pyplot as plt
import sys 
import os 
import scipy
import importlib

sys.path.insert(0, '/gpfs/loomis/project/david_moore/aj487/purity-monitor/')
sys.path.insert(0, '/gpfs/loomis/project/david_moore/aj487/purity-monitor/analysis/')
import HelperClasses as Dataset
import StandMonitor as Monitor
import PlotFunctions as Plt

# %% [markdown]
# # Data Read-In

# %%
# D1 = Dataset.Dataset(Path='/project/fas/david_moore/aj487/Data_WL110/LXe_Setup/TPC/20201223/', Selection='*C-40V*')
D1 = Dataset.Dataset(Path='/project/fas/david_moore/aj487/Data_WL110/LXe_Setup/TPC/20201223/', Selection='*')
D1.RunStandardAnalysis()
D1.ShowAmplitudeVsTime(YTicks=10, YMax=120)
plt.savefig('20201223_charge_all.pdf', bbox_inches='tight')

D1.ShowDrifttimeVsTime()
plt.savefig('20201223_drifttime_all.pdf', bbox_inches='tight')


D1.ShowBaselineNoise()
Plt.PltWfm(Time=D1.Ch[0].Time,
           Data=[np.mean(D1.Ch[0].AmpClean, axis=0), np.mean(D1.Ch[1].AmpClean, axis=0)/-1.0],
           Legend=['Anode'],
           XTicks=100,
           YTicks=10,
           SaveName='avg_waveform',
           Color='k')
plt.ylim(-30,30)
plt.xlim(-100,100)
plt.savefig('20201223_waveform_all.pdf', bbox_inches='tight')

Plt.PltWfm(Time=D1.Ch[0].Time,
           Data=list(D1.Ch[0].AmpClean),
           Legend=['Anode'],
           XTicks=100,
           YTicks=10,
           SaveName='avg_waveform',
           Color='k')
plt.ylim(-30,30)
plt.xlim(-100,100)
# Out:
#  | Filename... /project/fas/david_moore/aj487/Data_WL110/LXe_Setup/TPC/20201223/GAr_1bar_Au-Thorslabs_C-60V_A-1500V_purify_1.h5
#  | Number of files in ch1...	 90/90
#  | Number of files in ch2...	 90/90
#  | Filename... /project/fas/david_moore/aj487/Data_WL110/LXe_Setup/TPC/20201223/GAr_1bar_Au-Thorslabs_C-80V_A-2000V_1.h5
#  | Number of files in ch1...	 37/127
#  | Number of files in ch2...	 37/127
#  | Filename... /project/fas/david_moore/aj487/Data_WL110/LXe_Setup/TPC/20201223/GAr_1bar_Au-Thorslabs_C-75V_A-1500V_stop_purify_2.h5
#  | Number of files in ch1...	 50/177
#  | Number of files in ch2...	 50/177
#  | Filename... /project/fas/david_moore/aj487/Data_WL110/LXe_Setup/TPC/20201223/GAr_1bar_Au-Thorslabs_C-60V_A-1500V_purify_3.h5
#  | Number of files in ch1...	 19/196
#  | Number of files in ch2...	 19/196
#  | Filename... /project/fas/david_moore/aj487/Data_WL110/LXe_Setup/TPC/20201223/GAr_1bar_Au-Thorslabs_C-75V_A-1500V_purify_1.h5
#  | Number of files in ch1...	 18/214
# ...

# %%
D2 = Dataset.Dataset(Path='/project/fas/david_moore/aj487/Data_WL110/LXe_Setup/TPC/20201223/', Selection='*stop*')
D2.RunStandardAnalysis()
D2.ShowAmplitudeVsTime(YTicks=10)
D2.ShowDrifttimeVsTime()
D2.ShowBaselineNoise()
Plt.PltWfm(Time=D2.Ch[0].Time,
           Data=[np.mean(D2.Ch[0].AmpClean, axis=0), np.mean(D2.Ch[1].AmpClean, axis=0)/-1.0],
           Legend=['Anode'],
           XTicks=100,
           YTicks=5,
           SaveName='avg_waveform',
           Color='k')
plt.ylim(-30,30)
plt.xlim(-100,100)
plt.savefig('20201222_waveform_80Vcm.pdf', bbox_inches='tight')
# Out:
#  | Filename... /project/fas/david_moore/aj487/Data_WL110/LXe_Setup/TPC/20201223/GAr_1bar_Au-Thorslabs_C-75V_A-1500V_stop_purify_2.h5
#  | Number of files in ch1...	 50/50
#  | Number of files in ch2...	 50/50
#  | Filename... /project/fas/david_moore/aj487/Data_WL110/LXe_Setup/TPC/20201223/GAr_1bar_Au-Thorslabs_C-75V_A-1500V_stop_purify_1.h5
#  | Number of files in ch1...	 25/75
#  | Number of files in ch2...	 25/75
#  | Processing data in channel 1...
#  | Processing data in channel 2...
#  | Time elapsed:  24.587053945 sec
# Ticks:  10

# %%
D3 = Dataset.Dataset(Path='/project/fas/david_moore/aj487/Data_WL110/LXe_Setup/TPC/20201222/', Selection='*C-80V*')
D3.RunStandardAnalysis()
D3.ShowAmplitudeVsTime(YTicks=10)
D3.ShowDrifttimeVsTime()
D3.ShowBaselineNoise()
Plt.PltWfm(Time=D3.Ch[0].Time,
           Data=[np.mean(D3.Ch[0].AmpClean, axis=0), np.mean(D3.Ch[1].AmpClean, axis=0)/-1.0],
           Legend=['Anode'],
           XTicks=100,
           YTicks=5,
           SaveName='avg_waveform',
           Color='k')
plt.ylim(-30,30)
plt.xlim(-100,500)
plt.savefig('20201222_waveform_80Vcm.pdf', bbox_inches='tight')
# Out:
#  | Filename... /project/fas/david_moore/aj487/Data_WL110/LXe_Setup/TPC/20201222/GAr_1bar_Au-Thorslabs_C-80V_A-2000V_1.h5
#  | Number of files in ch1...	 50/50
#  | Number of files in ch2...	 50/50
#  | Processing data in channel 1...
#  | Processing data in channel 2...
#  | Time elapsed:  29.034610448 sec
# Ticks:  10
