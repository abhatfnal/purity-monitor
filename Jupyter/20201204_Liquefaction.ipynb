# %% [markdown]
# # Import and Setup

# %% [markdown]
# Adjust cell width to view more content

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %% [markdown]
# Import general packages and YLXPS-related packages

# %%
import numpy as np
import matplotlib.pyplot as plt
import sys 
import os 
import scipy
import importlib

sys.path.insert(0, '/gpfs/loomis/project/david_moore/aj487/purity_monitor/')
sys.path.insert(0, '/gpfs/loomis/project/david_moore/aj487/purity_monitor/analysis/')
import HelperClasses as Dataset
import StandMonitor as Monitor
import PlotFunctions as Plt

# %% [markdown]
# # Data Read-In

# %%
File = '/project/fas/david_moore/aj487/Data_WL110/LXe_Setup/Sensors/20201203.h5'
Sensors = Monitor.SensorData(Filepath=File)
Sensors.GetData()
Sensors.PlotData(Selection='Temperature', Ticks=[1,20], XRange=0, XTicks=2, YRange=[-110,30])
# plt.xlim('7:00', End)
Sensors.PlotData(Selection='Xenon Pressure', Ticks=[0,100], XRange=0, YRange=[0,800])
# plt.xlim('7:00', End)
Sensors.PlotData(Selection='System Pressure', Ticks=[0,5], XRange=0, YRange=[-15,12])
# plt.xlim('7:00', End)

# %%
Start = '0:00'
End = '19:00'
File = '/project/fas/david_moore/aj487/Data_WL110/LXe_Setup/Sensors/20201204.h5'
Sensors = Monitor.SensorData(Filepath=File)
Sensors.GetData()
Sensors.PlotData(Selection='Temperature', Ticks=[1,2], XRange=0, XTicks=20, YRange=[-110,50])
plt.xlim(Start, End)
Sensors.PlotData(Selection='Xenon Pressure', Ticks=[0,10], XRange=0, YRange=[0,100])
plt.xlim(Start, End)
Sensors.PlotData(Selection='System Pressure', Ticks=[0,1], XRange=0, YRange=[0,15])
plt.xlim(Start, End)
# Out:
# (737763.0, 737763.7916666666)

# %%
D1 = Dataset.Dataset(Path='/project/fas/david_moore/aj487/Data_WL110/LXe_Setup/TPC/20201204/', Selection='*')
D1.RunStandardAnalysis()
D1.ShowAmplitudeVsTime()
D1.ShowBaselineNoise()
print(D1.Ch[0].Time[1]-D1.Ch[0].Time[0])
# Out:
#  | Filename... /project/fas/david_moore/aj487/Data_WL110/LXe_Setup/TPC/20201204/Liquefaction_C-500V_A-500V_1.h5
#  | Number of files in ch1...	 59/59
#  | Number of files in ch2...	 59/59
#  | Filename... /project/fas/david_moore/aj487/Data_WL110/LXe_Setup/TPC/20201204/Liquefaction_C-1800V_A-1800Vdiff_no_fiber_1.h5
#  | Number of files in ch1...	 22/81
#  | Number of files in ch2...	 22/81
#  | Filename... /project/fas/david_moore/aj487/Data_WL110/LXe_Setup/TPC/20201204/Liquefaction_C-100V_A-100V_4.h5
#  | Number of files in ch1...	 34/115
#  | Number of files in ch2...	 34/115
#  | Filename... /project/fas/david_moore/aj487/Data_WL110/LXe_Setup/TPC/20201204/Liquefaction_C-100V_A-100V_10.h5
#  | Number of files in ch1...	 3/118
#  | Number of files in ch2...	 3/118
#  | Filename... /project/fas/david_moore/aj487/Data_WL110/LXe_Setup/TPC/20201204/Liquefaction_C-100V_A-100V_13.h5
#  | Number of files in ch1...	 52/170
#  | Number of files in ch2...	 52/170
# ...

# %%
D2 = Dataset.Dataset(Path='/project/fas/david_moore/aj487/Data_WL110/LXe_Setup/TPC/20201204/', Selection='*1800*')
D2.RunStandardAnalysis()
D2.ShowAmplitudeVsTime()
D2.ShowBaselineNoise()
Plt.PltWfm(Time=D2.Ch[0].Time,
           Data=[np.mean(D2.Ch[0].AmpClean, axis=0), np.mean(D2.Ch[1].AmpClean, axis=0)/-400.0],
           Legend=['Anode'],
           XTicks=100,
           YTicks=2,
           SaveName='avg_waveform',
           Color='k')
plt.ylim(-5,5)
plt.xlim(-100,500)
# Out:
#  | Filename... /project/fas/david_moore/aj487/Data_WL110/LXe_Setup/TPC/20201204/Liquefaction_C-1800V_A-1800Vdiff_no_fiber_1.h5
#  | Number of files in ch1...	 22/22
#  | Number of files in ch2...	 22/22
#  | Filename... /project/fas/david_moore/aj487/Data_WL110/LXe_Setup/TPC/20201204/Liquefaction_C-1800V_A-1800V_1.h5
#  | Number of files in ch1...	 125/147
#  | Number of files in ch2...	 125/147
#  | Filename... /project/fas/david_moore/aj487/Data_WL110/LXe_Setup/TPC/20201204/Liquefaction_C-1800V_A-1800V_2.h5
#  | Number of files in ch1...	 169/316
#  | Number of files in ch2...	 169/316
#  | Filename... /project/fas/david_moore/aj487/Data_WL110/LXe_Setup/TPC/20201204/Liquefaction_C-1800V_A-1800Vdiff_no_fiber_2.h5
#  | Number of files in ch1...	 23/339
#  | Number of files in ch2...	 23/339
#  | Processing data in channel 1...
#  | Processing data in channel 2...
#  | Time elapsed:  57.517810246 sec
# 300.0
# (-100, 500)

# %%
Plt.PltWfm(Time=D2.Ch[0].Time,
           Data=[np.mean(D2.Ch[0].AmpClean, axis=0), np.mean(D2.Ch[1].AmpClean, axis=0)/-400.0],
           Legend=['Anode'],
           XTicks=100,
           YTicks=2,
           SaveName='avg_waveform',
           Color='k')
plt.ylim(-5,5)
plt.xlim(-100,500)
# Out:
# (-100, 500)

# %%
D3 = Dataset.Dataset(Path='/project/fas/david_moore/aj487/Data_WL110/LXe_Setup/TPC/20201204/', Selection='*no_fiber*')
D3.RunStandardAnalysis()
# D3.ShowAmplitudeVsTime()
# D3.ShowBaselineNoise()
Plt.PltWfm(Time=D3.Ch[0].Time,
           Data=[np.mean(D3.Ch[0].AmpClean, axis=0), np.mean(D3.Ch[1].AmpClean, axis=0)],
           Legend=['Anode'],
           XTicks=100,
           YTicks=2,
           SaveName='avg_waveform',
           Color='k')
plt.ylim(-5,5)
plt.xlim(-100,500)
# Out:
#  | Filename... /project/fas/david_moore/aj487/Data_WL110/LXe_Setup/TPC/20201204/Liquefaction_C-1800V_A-1800Vdiff_no_fiber_1.h5
#  | Number of files in ch1...	 22/22
#  | Number of files in ch2...	 22/22
#  | Filename... /project/fas/david_moore/aj487/Data_WL110/LXe_Setup/TPC/20201204/Liquefaction_C-1800V_A-1800Vdiff_no_fiber_2.h5
#  | Number of files in ch1...	 23/45
#  | Number of files in ch2...	 23/45
#  | Processing data in channel 1...
#  | Processing data in channel 2...
#  | Time elapsed:  61.114246484 sec
# (-100, 500)
